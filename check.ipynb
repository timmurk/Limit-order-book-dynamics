# %%
import numpy as np 
from book import *
import matplotlib.pyplot as plt

# %%
alpha0, beta0 = 27.11, 27.09
np.random.seed(1)
T = 10
N = 10000
d1, d2, d3, d4 = 0.01, 0.2, 0.1, 0.1
kappa = 0.1
delta = 0.1
mu = 0.03
nu = 0.1
sigma0, sigma1, sigma2 = 0.1, 0.01, 0.1
Va0, Vb0 = 400, 400

params = {
    'd1': d1,
    'd2': d2,
    'd3': d3,
    'd4': d4,
    'kappa': kappa,
    'sigma0': sigma0,
    'sigma1': sigma1,
    'sigma2': sigma2,
    'Va0': Va0,
    'Vb0': Vb0,
    'mu': mu,
    'T': T,
    'N': N,
    'alpha0': alpha0,
    'beta0': beta0,
    'delta': delta,
    'nu': nu
}

b1 = Book(params)

# %%
alpha, beta, Va, Vb = b1.simmulate()

# %%
plot(Va, Vb, alpha, beta, True, 'figures.png')
